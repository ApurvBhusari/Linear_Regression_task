# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv",header=1,skiprows=[124,125,126])

# %%
df.shape
# Out:
# (244, 14)

# %%
df.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
#  RH              int64
#  Ws              int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC              object
# ISI            float64
# BUI            float64
# FWI             object
# Classes         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# dtype: int64

# %%
df[['DC']].replace(to_replace=" ",value="",inplace=True)
# Out:
# C:\Users\apurv\anaconda3\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes
# 0     3.4  0.5   not fire
# ...

# %%
df['Classes']=df['Classes'].map(lambda x:x.strip())
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5     8  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes
# ...

# %%
df[]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes
# 0     3.4  0.5   not fire
# ...

# %%
df.drop(columns='year',inplace=True)

# %%
a=df[['Temperature']]

# %%
a
# Out:
#     Temperature
# 0            29
# 1            29
# 2            26
# 3            25
# 4            27
# ..          ...
# 239          30
# 240          28
# 241          27
# 242          24
# 243          24
#
# [242 rows x 1 columns]

# %%
df.drop(columns='Temperature',inplace=True)

# %%
df['Region']=[1 if i<=121 else 0 for i in df.index]

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
col=[i.strip() for i in df.columns]
col
# Out:
# ['day',
#  'month',
#  'year',
#  'Temperature',
#  'RH',
#  'Ws',
#  'Rain',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI',
#  'Classes']

# %%
col
# Out:
# ['day',
#  'month',
#  'year',
#  'Temperature',
#  'RH',
#  'Ws',
#  'Rain',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI',
#  'Classes']

# %%
df.columns=col

# %%
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.isnull().sum()
# Out:
# day        0
# month      0
# RH         0
# Ws         0
# Rain       0
# FFMC       0
# DMC        0
# DC         0
# ISI        0
# BUI        0
# FWI        0
# Classes    0
# Region     0
# dtype: int64

# %%
a=df.dropna()

# %%
a.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
df['Classes'].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
df['Classes']=df['Classes'].map(lambda x:x.strip())

# %%
df['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
df
# Out:
#     day month  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  FWI   Classes  Region
# 0    01    06  57  18     0  65.7  3.4   7.6  1.3   3.4  0.5  not fire       1
# 1    02    06  61  13   1.3  64.4  4.1   7.6    1   3.9  0.4  not fire       1
# 2    03    06  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1  not fire       1
# 3    04    06  89  13   2.5  28.6  1.3   6.9    0   1.7    0  not fire       1
# 4    05    06  77  16     0  64.8    3  14.2  1.2   3.9  0.5  not fire       1
# ..   ..   ...  ..  ..   ...   ...  ...   ...  ...   ...  ...       ...     ...
# 239  26    09  65  14     0  85.4   16  44.5  4.5  16.9  6.5      fire       0
# 240  27    09  87  15   4.4  41.1  6.5     8  0.1   6.2    0  not fire       0
# 241  28    09  87  29   0.5  45.9  3.5   7.9  0.4   3.4  0.2  not fire       0
# 242  29    09  54  18   0.1  79.7  4.3  15.2  1.7   5.1  0.7  not fire       0
# 243  30    09  64  15   0.2  67.3  3.8  16.5  1.2   4.8  0.5  not fire       0
#
# [241 rows x 13 columns]

# %%
encoded_data=pd.get_dummies(df,columns=['Classes'],drop_first=True)
encoded_data.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes_not fire
# 0  0.5                 1
# 1  0.4                 1
# 2  0.1                 1
# 3    0                 1
# 4  0.5                 1

# %%
x_col=['day','month','RH','Ws','Rain','FFMC','DMC','DC','ISI','BUI','FWI',"Region",'Classes_not fire']

# %%
y_col=['Temperature']

# %%
encoded_data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes_not fire'],
#       dtype='object')

# %%
encoded_data.corr()
# Out:
#                     Region  Classes_not fire
# Region            1.000000          0.154415
# Classes_not fire  0.154415          1.000000

# %%
encoded_data.dtype
# Out:
# day                      object
# month                    object
# year                     object
# Temperature              object
# RH                       object
# Ws                       object
# Rain                     object
# FFMC                     object
# DMC                      object
# DC                       object
# ISI                      object
# BUI                      object
# FWI                      object
# Classes_fire              uint8
# Classes_fire              uint8
# Classes_fire              uint8
# Classes_not fire          uint8
# Classes_not fire          uint8
# Classes_not fire          uint8
# Classes_not fire          uint8
# Classes_not fire          uint8
# dtype: object

# %%
dict1={'day':int, 'month':int, 'RH':int, 'Ws':int, 'Rain':float, 'FFMC':float, 'DMC':float, 'DC':float, 'ISI':float, 'BUI':float,
       'FWI':float, 'Region':int, 'Classes_not fire':int}

# %%
pd.to_numeric(encoded_data['day'])
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 239    26
# 240    27
# 241    28
# 242    29
# 243    30
# Name: day, Length: 243, dtype: int64

# %%
encoded_data.iloc[115:125]
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC    DC  ...  \
# 115   24     09  2012           29   65   19    0.6  68.3  5.5  15.2  ...
# 116   25     09  2012           26   81   21    5.8  48.6    3   7.7  ...
# 117   26     09  2012           31   54   11      0    82    6  16.3  ...
# 118   27     09  2012           31   66   11      0  85.7  8.3  24.9  ...
# 119   28     09  2012           32   47   14    0.7  77.5  7.1   8.8  ...
# 121  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ...
# 122   01     06  2012           32   71   12    0.7  57.1  2.5   8.2  ...
# 123   02     06  2012           30   73   13      4  55.7  2.7   7.8  ...
# 124   03     06  2012           29   80   14      2  48.7  2.2   7.6  ...
# 125   04     06  2012           30   64   14      0  79.4  5.2  15.4  ...
#
#      BUI  FWI Classes_fire  Classes_fire   Classes_fire     Classes_not fire  \
# ...

# %%
encoded_data=encoded_data.astype({'day':, 'month':int,'year':int,'Temperature':int, 'RH':int, 'Ws':int, 'Rain':float, 'FFMC':float, 'DMC':float, 'DC':float, 'ISI':float, 'BUI':float,
       'FWI':float})
# Out:
#   Input In [833]
#     encoded_data=encoded_data.astype({'day':, 'month':int,'year':int,'Temperature':int, 'RH':int, 'Ws':int, 'Rain':float, 'FFMC':float, 'DMC':float, 'DC':float, 'ISI':float, 'BUI':float,
#                                             ^
# SyntaxError: invalid syntax

# %%
encoded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   day               243 non-null    int64
#  1   month             243 non-null    int64
#  2   year              243 non-null    int64
#  3   Temperature       243 non-null    int64
#  4   RH                243 non-null    int64
#  5   Ws                243 non-null    int64
#  6   Rain              243 non-null    float64
#  7   FFMC              243 non-null    float64
#  8   DMC               243 non-null    float64
#  9   DC                243 non-null    float64
#  10  ISI               243 non-null    float64
#  11  BUI               243 non-null    float64
#  12  FWI               243 non-null    object
#  13  Classes_not fire  243 non-null    uint8
# dtypes: float64(6), int64(6), object(1), uint8(1)
# memory usage: 34.9+ KB

# %%
encoded_data.corr()
# Out:
#                        day     month        RH        Ws      Rain      FFMC  \
# day               1.000000 -0.018084 -0.092244  0.050800 -0.119184  0.261497
# month            -0.018084  1.000000 -0.054769 -0.038226  0.030396  0.042918
# RH               -0.092244 -0.054769  1.000000  0.247039  0.219691 -0.640474
# Ws                0.050800 -0.038226  0.247039  1.000000  0.172069 -0.173693
# Rain             -0.119184  0.030396  0.219691  0.172069  1.000000 -0.547942
# FFMC              0.261497  0.042918 -0.640474 -0.173693 -0.547942  1.000000
# DMC               0.511621  0.079968 -0.402953 -0.002301 -0.286753  0.600086
# DC                0.546587  0.137818 -0.220492  0.078146 -0.296148  0.503168
# ISI               0.197503  0.078692 -0.683436  0.006952 -0.345682  0.738807
# BUI               0.537446  0.097206 -0.347785  0.030078 -0.297876  0.588315
# FWI               0.367894  0.094125 -0.577321  0.031137 -0.322593  0.690614
# ...

# %%
encoded_data.describe()
# Out:
#               day       month          RH          Ws        Rain        FFMC  \
# count  241.000000  241.000000  241.000000  241.000000  241.000000  241.000000
# mean    15.647303    7.489627   61.900415   15.497925    0.756017   78.104979
# std      8.789440    1.110976   14.808164    2.821236    2.009989   14.113937
# min      1.000000    6.000000   21.000000    6.000000    0.000000   28.600000
# 25%      8.000000    7.000000   52.000000   14.000000    0.000000   72.600000
# 50%     16.000000    7.000000   63.000000   15.000000    0.000000   83.700000
# 75%     23.000000    8.000000   73.000000   17.000000    0.500000   88.300000
# max     31.000000    9.000000   90.000000   29.000000   16.800000   96.000000
#
#               DMC          DC         ISI         BUI         FWI      Region  \
# count  241.000000  241.000000  241.000000  241.000000  241.000000  241.000000
# mean    14.782573   49.778008    4.779668   16.806639    7.092946    0.497925
# ...

# %%
df
# Out:
#     day month  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  FWI   Classes  Region
# 0    01    06  57  18     0  65.7  3.4   7.6  1.3   3.4  0.5  not fire       1
# 1    02    06  61  13   1.3  64.4  4.1   7.6    1   3.9  0.4  not fire       1
# 2    03    06  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1  not fire       1
# 3    04    06  89  13   2.5  28.6  1.3   6.9    0   1.7    0  not fire       1
# 4    05    06  77  16     0  64.8    3  14.2  1.2   3.9  0.5  not fire       1
# ..   ..   ...  ..  ..   ...   ...  ...   ...  ...   ...  ...       ...     ...
# 239  26    09  65  14     0  85.4   16  44.5  4.5  16.9  6.5      fire       0
# 240  27    09  87  15   4.4  41.1  6.5     8  0.1   6.2    0  not fire       0
# 241  28    09  87  29   0.5  45.9  3.5   7.9  0.4   3.4  0.2  not fire       0
# 242  29    09  54  18   0.1  79.7  4.3  15.2  1.7   5.1  0.7  not fire       0
# 243  30    09  64  15   0.2  67.3  3.8  16.5  1.2   4.8  0.5  not fire       0
#
# [241 rows x 13 columns]

# %%
b=df[['FFMC']]

# %%
a['FFMC'].dtypes
# Out:
# dtype('O')

# %%
a.dtypes
# Out:
# FFMC    object
# dtype: object

# %%
a
# Out:
#      FFMC
# 0    65.7
# 1    64.4
# 2    47.1
# 3    28.6
# 4    64.8
# ..    ...
# 239  85.4
# 240  41.1
# 241  45.9
# 242  79.7
# 243  67.3
#
# [242 rows x 1 columns]

# %%
a.dtypes
# Out:
# FFMC    object
# dtype: object

# %%
encoded_data.dtypes
# Out:
# day                   int32
# month                 int32
# RH                    int32
# Ws                    int32
# Rain                float64
# FFMC                float64
# DMC                 float64
# DC                  float64
# ISI                 float64
# BUI                 float64
# FWI                 float64
# Region                int32
# Classes_not fire      int32
# dtype: object

# %%
sns.kdeplot(a)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
sns.kdeplot(a,color='violet',fill='violet')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
encoded_data[['day']]
# Out:
#      day
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 239   26
# 240   27
# 241   28
# 242   29
# 243   30
#
# [241 rows x 1 columns]

# %%
sns.kdeplot(encoded_data['day'])
# Out:
# <AxesSubplot: xlabel='day', ylabel='Density'>

# %%
#univariate analysis of features

plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
for i in range(0, len(x_col)-1):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=encoded_data[x_col[i]],fill=True, color='b')
    plt.xlabel(x_col[i])
    plt.tight_layout()

# %% [markdown]
# here we can observe that the rain, dmc ,dc, isi,bui,fwi are positively skewed or right skewed whereas only ffmc is negatively skewed or left skewed

# %%
a=df['Temperature']

# %%
plt.figure(figsize=(4,4))
plt.suptitle("univariate analysis of numerical label",fontsize=20,fontweight='bold',alpha=0.8,y=1.)
sns.kdeplot(x=a,fill=True)
# Out:
# <AxesSubplot: xlabel='Temperature', ylabel='Density'>

# %%
temperature is showing normal distribution

# %%
plt.figure(figsize=(15,15))
sns.displot(a)

# %%
plt.figure(figsize=(12,12))
sns.heatmap(encoded_data.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# we can observe that dc,dmc and bui are highly correlated

# %%
encoded_data['Region']=[1 if i<121 else 0 for i in df.index]

# %%
encoded_data
# Out:
#      day  month  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0      1      6           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1      2      6           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2      3      6           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3      4      6           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7    0
# 4      5      6           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..   ...    ...          ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 239   26      9           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 240   27      9           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2    0
# 241   28      9           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 242   29      9           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 243   30      9           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#      Classes_not fire  Region
# ...

# %%
x_col=['day','month','RH','Ws','Rain','FFMC','ISI','BUI','FWI','Classes_not fire','Region']

# %%
y_col=['Temperature']

# %%
encoded_data
# Out:
#      day  month  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0      1      6           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1      2      6           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2      3      6           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3      4      6           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7    0
# 4      5      6           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..   ...    ...          ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 239   26      9           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 240   27      9           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2    0
# 241   28      9           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 242   29      9           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 243   30      9           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#      Classes_not fire  Region
# ...

# %%
plt.figure(figsize=(20,20))
sns.pairplot(encoded_data)

# %%
sns.scatterplot(x=encoded_data['Rain'],y=encoded_data['Temperature'])
# Out:
# <AxesSubplot: xlabel='Rain', ylabel='Temperature'>

# %% [markdown]
# here we can observe that lesser the rain more the temperature

# %%
sns.scatterplot(x=encoded_data['FFMC'],y=encoded_data['Temperature'])
# Out:
# <AxesSubplot: xlabel='FFMC', ylabel='Temperature'>

# %% [markdown]
# as the temperature is increasing ffmc is also increasing
#     temperature has linear relationship with ffmc

# %%
sns.scatterplot(y=encoded_data['Temperature'],x=encoded_data['BUI'])
# Out:
# <AxesSubplot: xlabel='BUI', ylabel='Temperature'>

# %%
sns.regplot(x='FFMC',y='Temperature',data=encoded_data)
# Out:
# <AxesSubplot: xlabel='FFMC', ylabel='Temperature'>

# %%
sns.regplot(x='Rain',y="Temperature",data=encoded_data)
# Out:
# <AxesSubplot: xlabel='Rain', ylabel='Temperature'>

# %%
sns.boxplot(encoded_data['FFMC'])
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(x=encoded_data['Rain'])
# Out:
# <AxesSubplot: xlabel='Rain'>

# %%
sns.boxplot(encoded_data['BUI'])
# Out:
# <AxesSubplot: >

# %%
X=encoded_data[x_col]
X
# Out:
#      day  month  RH  Ws  Rain  FFMC  ISI   BUI  FWI  Classes_not fire  Region
# 0      1      6  57  18   0.0  65.7  1.3   3.4  0.5                 1       1
# 1      2      6  61  13   1.3  64.4  1.0   3.9  0.4                 1       1
# 2      3      6  82  22  13.1  47.1  0.3   2.7  0.1                 1       1
# 3      4      6  89  13   2.5  28.6  0.0   1.7    0                 1       1
# 4      5      6  77  16   0.0  64.8  1.2   3.9  0.5                 1       1
# ..   ...    ...  ..  ..   ...   ...  ...   ...  ...               ...     ...
# 239   26      9  65  14   0.0  85.4  4.5  16.9  6.5                 0       0
# 240   27      9  87  15   4.4  41.1  0.1   6.2    0                 1       0
# 241   28      9  87  29   0.5  45.9  0.4   3.4  0.2                 1       0
# 242   29      9  54  18   0.1  79.7  1.7   5.1  0.7                 1       0
# 243   30      9  64  15   0.2  67.3  1.2   4.8  0.5                 1       0
#
# [243 rows x 11 columns]

# %%
y=encoded_data['Temperature']
y.head()
# Out:
# 0    29
# 1    29
# 2    26
# 3    25
# 4    27
# Name: Temperature, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=10)

# %%
x_train
# Out:
#      day  month  RH  Ws  Rain  FFMC   ISI   BUI   FWI  Classes_not fire  \
# 25    26      6  64  18   0.0  86.8   6.7  21.6  10.6                 0
# 121   30      9  78  14   1.4  45.0   0.2   2.4   0.1                 1
# 174   23      7  71  17   0.0  87.3   6.9  46.5  16.3                 0
# 72    12      8  51  13   0.3  81.3   2.5  20.7   4.2                 1
# 186    4      8  35  15   0.0  93.8  15.7  22.9  20.9                 0
# ..   ...    ...  ..  ..   ...   ...   ...   ...   ...               ...
# 64     4      8  69  13   0.0  85.0   4.0   8.2   3.9                 0
# 15    16      6  89  13   0.7  36.1   0.0   2.2     0                 1
# 229   16      9  26  13   0.0  93.9  14.2  22.4  19.3                 0
# 125    4      6  64  14   0.0  79.4   2.2   5.6     1                 1
# 9     10      6  79  12   0.0  73.2   1.3  12.6   0.9                 1
#
#      Region
# 25        1
# 121       0
# 174       0
# 72        1
# 186       0
# ..      ...
# ...

# %%
y_train
# Out:
# 25     31
# 121    25
# 174    31
# 72     35
# 186    38
#        ..
# 64     34
# 15     29
# 229    33
# 125    30
# 9      28
# Name: Temperature, Length: 162, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(x_train)

# %%
X_test=scaler.transform(x_test)

# %%
X_train
# Out:
# array([[ 1.30705791, -1.39305207,  0.06835876, ...,  0.52024214,
#         -0.90566259,  1.02500386],
#        [ 1.77217242,  1.29354835,  0.99672801, ..., -0.93452011,
#          1.10416397, -0.97560608],
#        [ 0.95822202, -0.4975186 ,  0.53254338, ...,  1.30997022,
#         -0.90566259, -0.97560608],
#        ...,
#        [ 0.14427163,  1.29354835, -2.45150064, ...,  1.72561657,
#         -0.90566259, -0.97560608],
#        [-1.2510719 , -1.39305207,  0.06835876, ..., -0.8098262 ,
#          1.10416397, -0.97560608],
#        [-0.55340014, -1.39305207,  1.0630401 , ..., -0.82368108,
#          1.10416397,  1.02500386]])

# %%
X_test
# Out:
# array([[ 2.60550258e-01, -4.97518595e-01,  4.66231295e-01,
#         -5.81850675e-01, -4.24064583e-01,  3.74594357e-01,
#         -3.54971234e-01, -3.70810009e-01, -4.49599362e-01,
#         -9.05662586e-01,  1.02500386e+00],
#        [-2.04564252e-01,  1.29354835e+00, -9.26322582e-01,
#          1.26638088e+00, -4.24064583e-01,  7.58044470e-01,
#          1.05400512e+00, -2.76631780e-01,  4.78677502e-01,
#         -9.05662586e-01, -9.75606083e-01],
#        [ 1.77217242e+00, -4.97518595e-01, -4.62137956e-01,
#          1.57441947e-01, -4.24064583e-01,  7.77878096e-01,
#          8.39076521e-01,  5.49238849e-01,  8.80468981e-01,
#         -9.05662586e-01, -9.75606083e-01],
#        [ 1.19077928e+00,  1.29354835e+00,  1.19566428e+00,
#          2.00567350e+00,  3.00789995e+00, -1.88643906e+00,
#         -1.02363798e+00, -9.57612824e-01, -9.34520112e-01,
#          1.10416397e+00,  1.02500386e+00],
#        [-1.36735053e+00, -1.39305207e+00,  1.12935219e+00,
# ...

# %% [markdown]
# LInear regression........................

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [-0.04005871 -0.16898028 -0.10097098 -0.25653127 -0.15173028  0.0562183
#   0.0212543   0.07186522 -0.06970604 -0.37447524 -0.22905224]

# %%
regression.intercept_
# Out:
# 39.56017536957195

# %%
reg_pred=regression.predict(x_test)

# %%
sns.scatterplot(x=y_test,y=reg_pred)
plt.xlabel(' actual test data')
plt.ylabel("predicted data")
# Out:
# Text(0, 0.5, 'predicted data')

# %% [markdown]
# the relationship of both actual test data and predicted test data is linear

# %%
residual=y_test-reg_pred
residual
# Out:
# 46    -3.077508
# 226   -4.044429
# 181    2.620959
# 116    1.062148
# 124   -0.003152
#          ...
# 127   -0.240109
# 242   -7.252455
# 208   -4.275420
# 102    2.976142
# 78     2.725663
# Name: Temperature, Length: 81, dtype: float64

# %%
sns.kdeplot(residual)
# Out:
# <AxesSubplot: xlabel='Temperature', ylabel='Density'>

# %%
plt.scatter(reg_pred,residual)

# %%
from sklearn.metrics  import mean_squared_error,mean_absolute_error
print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 2.1637055781536128
# 7.860718693294244
# 2.803697325549647

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.43215256598802587

# %%
adjR = 1 - ( 1-score ) * ( len(y) - 1 ) / ( len(y) - X.shape[1] - 1 )
print(adjR)
# Out:
# 0.40511221198745573

# %% [markdown]
# #RIDGE REGRESSION

# %%
from sklearn.linear_model import Ridge
ridge_reg=Ridge(alpha=0.1)

# %%
ridge_reg
# Out:
# Ridge(alpha=0.1)

# %%
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.1)

# %%
ridge_reg.coef_
# Out:
# array([-0.3436173 , -0.18873826, -1.51984495, -0.69410753, -0.25634494,
#         0.85288058,  0.07944483,  0.98124146, -0.48438406, -0.18500333,
#        -0.11482803])

# %%
ridge_reg.intercept_
# Out:
# 32.074074074074076

# %%
rid_pred=ridge_reg.predict(X_test)
rid_pred
# Out:
# array([32.0774794 , 33.04432071, 33.3829547 , 24.94113637, 29.00545445,
#        33.84936872, 31.77226768, 34.81866327, 31.77130245, 32.69008332,
#        33.64311485, 33.38959567, 35.766334  , 31.96256045, 33.60221459,
#        33.27730272, 26.70214612, 35.88229823, 33.30106862, 23.88971812,
#        32.05126754, 32.763861  , 32.99712588, 32.98992751, 29.8494266 ,
#        32.74457692, 33.11108306, 32.12606207, 32.16777165, 34.19334576,
#        34.62455183, 33.76063533, 34.6593274 , 32.73200912, 31.42672526,
#        28.62087922, 32.63147079, 31.69865955, 32.76292091, 34.17346171,
#        33.95745142, 35.60554231, 34.35438329, 37.51991241, 32.9571598 ,
#        36.55489653, 32.29043265, 35.19466429, 30.45932909, 31.06955248,
#        32.47155627, 39.04146341, 32.75755756, 34.76517842, 27.27899683,
#        37.07202753, 33.90395875, 33.6381958 , 28.88893016, 32.46028144,
#        32.4408192 , 32.06414913, 24.75476574, 36.47150567, 36.47734025,
# ...

# %%
plt.scatter(y_test,rid_pred)
plt.xlabel("test truth data")
plt.ylabel('test truth data')
# Out:
# Text(0, 0.5, 'test truth data')

# %%
residual_ridge=y_test-rid_pred
residual_ridge
# Out:
# 46    -3.077479
# 226   -4.044321
# 181    2.617045
# 116    1.058864
# 124   -0.005454
#          ...
# 127   -0.237287
# 242   -7.253806
# 208   -4.277744
# 102    2.974191
# 78     2.722862
# Name: Temperature, Length: 81, dtype: float64

# %%
sns.displot(residual_ridge,kind='kde')

# %%
plt.scatter(rid_pred,residual)

# %% [markdown]
# Performance_metric

# %%
mean_absolute_error(y_test,rid_pred)
mean_squared_error(y_test,rid_pred)
np.sqrt(mean_squared_error(y_test,rid_pred))
# Out:
# 2.8029875458077584

# %%
ridge_score=r2_score(y_test,rid_pred)
ridge_score
# Out:
# 0.4324400403770339

# %%
adjR2 = 1 - ( 1-ridge_score ) * ( len(y) - 1 ) / ( len(y) - X.shape[1] - 1 )
print(adjR2)
# Out:
# 0.4054133756330831

# %% [markdown]
# lasso regression

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.1)
lasso
# Out:
# Lasso(alpha=0.1)

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
lasso.coef_
# Out:
# array([-0.09399839, -0.06625722, -1.37665034, -0.63896218, -0.15649734,
#         1.01411503,  0.        ,  0.44238765,  0.        , -0.04058745,
#        -0.02921361])

# %%
lasso.intercept_
# Out:
# 32.074074074074076

# %%
ls_pred=lasso.predict(X_test)

# %%
plt.scatter(y_test,ls_pred) # if you get linear manner it is good linear model
plt.xlabel('Test Truth Data')
plt.ylabel('Test Predict Data')
# Out:
# Text(0, 0.5, 'Test Predict Data')

# %%
residual_lasso=y_test-ls_pred
residual_lasso
# Out:
# 46    -3.101510
# 226   -4.251639
# 181    2.360481
# 116   -0.066685
# 124    0.366011
#          ...
# 127    0.497900
# 242   -7.935014
# 208   -3.867992
# 102    2.400213
# 78     2.484802
# Name: Temperature, Length: 81, dtype: float64

# %%
sns.displot(residual,kind='kde')

# %%
plt.scatter(ls_pred,residual)

# %%
print(mean_squared_error(y_test,ls_pred))
print(mean_absolute_error(y_test,ls_pred))
print(np.sqrt(mean_squared_error(y_test,ls_pred)))
# Out:
# 7.627665980524347
# 2.1376375764416555
# 2.761822945180293

# %%
lasso_score = r2_score(y_test,ls_pred)
print(lasso_score)
# Out:
# 0.44898797126067724

# %%
adjR_lasso = 1 - ( 1-lasso_score ) * ( len(y) - 1 ) / ( len(y) - X.shape[1] - 1 )
print(adjR_lasso)
# Out:
# 0.42274930322547133

# %% [markdown]
# Elastic_net

# %%
from sklearn.linear_model import ElasticNet
el_reg = ElasticNet(random_state=0)
el_reg
# Out:
# ElasticNet(random_state=0)

# %%
el_reg.fit(X_train,y_train)
# Out:
# ElasticNet(random_state=0)

# %%
el_reg.coef_
# Out:
# array([ 0.        , -0.        , -0.77305615, -0.2692124 , -0.02583763,
#         0.68370998,  0.18955226,  0.08710602,  0.13176577, -0.12659504,
#        -0.        ])

# %%
el_reg.intercept_
# Out:
# 32.074074074074076

# %%
el_pred=el_reg.predict(X_test)
el_pred
# Out:
# array([32.09318845, 33.33190585, 33.3693061 , 28.70194587, 29.5053684 ,
#        33.21083804, 31.64650373, 33.91131323, 32.20508381, 32.62773328,
#        32.5230823 , 32.81776973, 34.34617943, 32.01331302, 32.6833583 ,
#        33.41933683, 29.25316159, 35.1446813 , 32.52873009, 28.80746971,
#        32.0682555 , 31.91467877, 32.87491333, 32.07262957, 30.71812105,
#        32.84344243, 32.82404675, 31.70569991, 31.7584041 , 32.53790961,
#        33.46631091, 33.10273115, 33.30374637, 32.7237694 , 31.4101003 ,
#        29.88095287, 32.19829514, 31.65134711, 33.35856435, 32.79552477,
#        33.59481921, 34.14347793, 33.542183  , 34.3512908 , 32.89187864,
#        35.45500806, 31.90029528, 34.23754119, 31.01024465, 31.53196548,
#        32.43998846, 36.60556013, 32.18745623, 34.00565319, 29.14210042,
#        35.16362501, 33.47923104, 32.43898636, 29.82021447, 32.20845065,
#        32.4226351 , 31.34461076, 28.36534075, 35.07875749, 34.36168324,
# ...

# %%
plt.scatter(y_test,el_pred) # if you get linear manner it is good linear model
plt.xlabel('Test Truth Data')
plt.ylabel('Test Predict Data')
# Out:
# Text(0, 0.5, 'Test Predict Data')

# %%
residual_elastic = y_test-el_pred
residual_elastic
# Out:
# 46    -3.093188
# 226   -4.331906
# 181    2.630694
# 116   -2.701946
# 124   -0.505368
#          ...
# 127    1.773925
# 242   -7.960550
# 208   -2.280130
# 102    0.552801
# 78     2.560403
# Name: Temperature, Length: 81, dtype: float64

# %%
sns.displot(residual,kind='kde')

# %%
plt.scatter(el_pred,residual)

# %%
print(mean_squared_error(y_test,el_pred))
print(mean_absolute_error(y_test,el_pred))
print(np.sqrt(mean_squared_error(y_test,el_pred)))
# Out:
# 7.940856720025196
# 2.292756781349445
# 2.8179525759006654

# %%
elastic_score = r2_score(y_test,el_pred)
print(elastic_score)
# Out:
# 0.42636350590058447

# %%
adjR_elasti = 1 - ( 1-elastic_score ) * ( len(y) - 1 ) / ( len(y) - X.shape[1] - 1 )
print(adjR_elasti)
# Out:
# 0.3990474823720409
